# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.metrics import silhouette_samples
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('../../dataset/weatherClean.csv')

# %%
df.describe()
# Out:
#             Location        MinTemp       Rainfall    Evaporation  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean        0.221213      12.186400       2.349974       5.302343
# std         0.064960       6.388924       8.423217       4.147637
# min         0.067224      -8.500000       0.000000       0.000000
# 25%         0.185234       7.600000       0.000000       2.400000
# 50%         0.222714      12.000000       0.000000       4.400000
# 75%         0.266917      16.800000       0.800000       7.200000
# max         0.363151      33.900000     371.000000     145.000000
#
#             Sunshine    WindGustDir  WindGustSpeed     WindDir9am  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean        7.377594       9.433756      39.984292       8.202239
# std         3.898898       5.188836      13.138385       5.515461
# min         0.000000       1.000000       6.000000       1.000000
# 25%         4.400000       5.000000      31.000000       3.000000
# 50%         8.100000       9.000000      39.000000       8.000000
# 75%        10.500000      15.000000      46.000000      12.000000
# max        14.500000      18.000000     135.000000      18.000000
#
#           WindDir3pm   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean        9.092649      14.001988      18.637576      68.843810
# std         5.107987       8.851082       8.721551      18.932077
# min         1.000000       0.000000       0.000000       0.000000
# 25%         5.000000       7.000000      13.000000      57.000000
# 50%         8.000000      13.000000      18.637576      70.000000
# 75%        12.000000      19.000000      24.000000      83.000000
# max        18.000000     130.000000      87.000000     100.000000
#
#          Humidity3pm    Pressure9am       Cloud9am       Cloud3pm  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean       51.482606    1017.653758       4.389750       4.258511
# std        20.532065       6.746248       2.879055       2.745819
# min         0.000000     980.500000       0.000000       0.000000
# 25%        37.000000    1013.500000       1.000000       1.000000
# 50%        51.482606    1017.653758       5.000000       5.000000
# 75%        65.000000    1021.800000       7.000000       7.000000
# max       100.000000    1041.000000       9.000000       9.000000
#
#            RainToday   RainTomorrow          Month
# count  142193.000000  142193.000000  142193.000000
# mean        0.221213       0.224181       6.402544
# std         0.415065       0.417043       3.426506
# min         0.000000       0.000000       1.000000
# 25%         0.000000       0.000000       3.000000
# 50%         0.000000       0.000000       6.000000
# 75%         0.000000       0.000000       9.000000
# max         1.000000       1.000000      12.000000

# %%
X = df.drop('RainTomorrow', axis=1)
Y = df['RainTomorrow']
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)
#X = X_test
#Y = y_test

# %% [markdown]
# Normalizacija

# %%
scaler = MinMaxScaler()
feature_names = X.columns
X = pd.DataFrame(scaler.fit_transform(X), columns=feature_names)
X
# Out:
#         Location   MinTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0       0.309164  0.629717  0.000000     0.068966  0.000000     0.000000
# 1       0.000000  0.792453  0.000000     0.080000  0.000000     0.352941
# 2       0.023888  0.698113  0.000000     0.102069  0.000000     0.647059
# 3       0.000000  0.674528  0.000000     0.071724  0.000000     0.058824
# 4       0.641075  0.412736  0.000000     0.091034  0.000000     0.882353
# ...          ...       ...       ...          ...       ...          ...
# 142188  1.000000  0.363208  0.000539     0.045517  0.986207     0.235294
# 142189  0.434720  0.483491  0.000000     0.055172  0.986207     0.352941
# 142190  0.139189  0.502358  0.000000     0.082759  1.000000     0.352941
# 142191  0.309164  0.457547  0.002695     0.036568  0.508800     0.823529
# 142192  0.329896  0.487887  0.000000     0.036568  0.508800     0.235294
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0            0.325581    0.000000    1.000000      0.200000      0.252874
# 1            0.271318    0.235294    0.352941      0.184615      0.068966
# 2            0.496124    0.941176    0.941176      0.200000      0.218391
# 3            0.356589    0.058824    0.882353      0.146154      0.321839
# 4            0.643411    0.000000    0.941176      0.230769      0.471264
# ...               ...         ...         ...           ...           ...
# 142188       0.209302    0.176471    0.176471      0.115385      0.218391
# 142189       0.271318    0.352941    0.294118      0.146154      0.195402
# 142190       0.240310    0.411765    0.352941      0.115385      0.229885
# 142191       0.263444    0.647059    0.352941      0.169231      0.214225
# 142192       0.170543    0.352941    0.411765      0.084615      0.126437
#
#         Humidity9am  Humidity3pm  Pressure9am  Cloud9am  Cloud3pm  RainToday  \
# 0          0.170000     0.090000     0.614112  0.000000  0.777778        0.0
# 1          0.140000     0.090000     0.533884  0.000000  0.777778        0.0
# 2          0.130000     0.090000     0.485950  0.000000  0.777778        0.0
# 3          0.210000     0.090000     0.363636  0.000000  0.777778        0.0
# 4          0.330000     0.130000     0.423140  0.000000  0.777778        0.0
# ...             ...          ...          ...       ...       ...        ...
# 142188     0.630000     0.530000     0.634711  0.111111  0.000000        0.0
# 142189     0.520000     0.100000     0.619835  0.333333  0.222222        0.0
# 142190     0.450000     0.170000     0.714050  0.000000  0.000000        0.0
# 142191     0.688438     0.514826     0.614112  0.487750  0.473168        0.0
# 142192     0.688438     0.514826     0.565289  0.487750  0.473168        0.0
#
#            Month
# 0       0.181818
# 1       0.000000
# 2       0.909091
# 3       0.090909
# 4       1.000000
# ...          ...
# 142188  0.000000
# 142189  1.000000
# 142190  1.000000
# 142191  0.545455
# 142192  0.363636
#
# [142193 rows x 18 columns]

# %% [markdown]
# Vizuelizacija

# %%
def find_boundaries(df, name):
    
    Q1=df[name].quantile(0.25)
    Q3=df[name].quantile(0.75)
    IQR=Q3-Q1
    lower_boundary = Q1-1.5*IQR
    upper_boundary = Q3+1.5*IQR
    return lower_boundary, upper_boundary

# %%
def outliers(name,df):
    lower_rainfall, upper_rainfall = find_boundaries(df, name)
    print('Gornja granica', upper_rainfall)
    print('Donja granica', lower_rainfall)
    outliers_rainfall = np.where(df[name] > upper_rainfall, True,
                            np.where(df[name] < lower_rainfall, True, False))

    print(outliers_rainfall)
    return len(df[outliers_rainfall]), outliers_rainfall

# %%
l, out = outliers('Evaporation',X)
X = X[~(out)]
Y = Y[~(out)]
print(len(df))

l, out = outliers('WindSpeed9am',X)
X = X[~(out)]
Y = Y[~(out)]
print(len(df))
# Out:
# Gornja granica 0.09931034482758619
# Donja granica -0.03310344827586206
# [False False  True ... False False False]
# 142193
# Gornja granica 0.2846153846153846
# Donja granica -0.08461538461538462
# [False False False ... False False False]
# 142193

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
scatter = plt.scatter(X_pca[:,0], X_pca[:,1],c=Y)
plt.xlabel('Prva glavna komponenta')
plt.ylabel('Druga glavna komponenta')
plt.title('Vizuelizacija skupa podataka pomoću PCA')
plt.legend(handles=scatter.legend_elements()[0], labels=['No', 'Yes'])

plt.show()

# %%
ks = range(2, 6)
for k in ks:
    kmeans = KMeans(n_clusters=k,init='k-means++')
    kmeans.fit(X)
    silhouette_values = silhouette_score(X, kmeans.labels_)
    print('Silueta za k = {}: {}'.format(k,silhouette_values))
    print(kmeans.inertia_)

# %%
centers = pd.DataFrame(kmeans.cluster_centers_)
centers.iloc[1]

# %%
ks = range(2, 10)
silhouette = []
for k in ks:
    kmeans = KMeans(n_clusters=k,init='k-means++')
    kmeans.fit(X_pca)
    silhouette_values = silhouette_score(X_pca, kmeans.labels_)
    silhouette.append(silhouette_values)
    print('Silueta za k = {}: {}'.format(k,silhouette_values))
    print(kmeans.inertia_)
plt.plot(ks, silhouette, marker="o")
plt.ylabel('silhouette coefs')
plt.xlabel('num_of_clusters')
plt.title('Silhouette coefs')

# %%
kmeans = KMeans(n_clusters=2,init='k-means++')
kmeans.fit(X_pca)

# %%
centers = pd.DataFrame(kmeans.cluster_centers_)
np.unique(kmeans.labels_)

# %%
plt.scatter(centers[0], centers[1], marker='X', label='centroids')

for c in np.unique(kmeans.labels_):
    elems = X_pca[kmeans.labels_ == c]
    plt.scatter(elems[0], elems[1], label=c)

plt.xlabel('0')
plt.ylabel('1')
plt.title('Two clusters with sse {}'.format(round(kmeans.inertia_, 2)))
plt.legend()
plt.show()

# %%
X_restored = pca.inverse_transform(centers)
X_restored = scaler.inverse_transform(X_restored)

# %%
new_df = pd.DataFrame(X_restored)
new_df.columns = X.columns

# %%
new_df

# %%
len(kmeans.labels_)

# %%
silhouette_values = silhouette_score(X_pca, kmeans.labels_)
silhouette_values
